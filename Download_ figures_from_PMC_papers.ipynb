# %%
import requests
import json
from bs4 import BeautifulSoup
import pandas as pd
import time
import shutil
import requests
import os
import re

# %% [markdown]
# # get figures from pm id

# %%
base_article_url = 'https://www.ncbi.nlm.nih.gov/pmc/articles/'
not_found_ids = []
no_pathway_papers = []

def create_no_pathway_file():
    
    with open('no_pathway.txt', 'w') as f:
        for id in no_pathway_papers:
            f.write("%s\n" % id)

def create_not_found_file():
    
    with open('not_found_ids.txt', 'w') as f:
        for id in not_found_ids:
            f.write("%s\n" % id)

def pubmed_id_to_PMC(id):
    
    a = requests.get("https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/?ids=" + str(id) + "&format=json")
    all_id =  a.json()
    all_list = all_id.get('records')
    b = list(all_list[0].values())
    
    if b[0][:3] != 'PMC':
        not_found_ids.append(id)
    
    return b[0]

def get_page_soup(PMC):
    
    page = requests.get(base_article_url + PMC + '/')
    soup = BeautifulSoup(page.content, 'html.parser')
    
    return soup

def get_captions(soup):
    
    caption_elements = soup.find_all(lambda tag: tag.name == 'div' and tag.get('class') == ['caption'])
    captions = [caption_element.findChild().text for caption_element in  caption_elements]
    
    return captions

def get_figure_numbers(soup):
    
    img_elements = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class') == ['figpopup'])
    fig_numbers = [img_element.text for img_element in img_elements]
    
    return fig_numbers
    
def get_img_names(soup):
       
    img_elements = soup.find_all('img', class_ = 'tileshop')
    sources = [img_element['src'] for img_element in img_elements]
    after_bins = [re.search("(bin(.*))", source).group() for source in sources]
    
    return after_bins

def get_image(PMC, source, figure_number, id):

    response = requests.get(base_article_url + PMC + '/' + source, stream=True)
    
    save_path = 'output/'+ str(id)
    try:
        os.makedirs(save_path)
    except:
        print(save_path + ' exists')
    
    with open(save_path + '/' + figure_number + '.jpg', 'wb') as out_file:
        shutil.copyfileobj(response.raw, out_file)
        
def take_imgs_from_site(id):
    
    PMC = pubmed_id_to_PMC(id)
    soup = get_page_soup(PMC)   
    
    captions = get_captions(soup)
    sources = get_img_names(soup)
    figure_numbers = get_figure_numbers(soup)
    
    pathway_found_counter = 0
    for source, figure_number, caption in zip(sources, figure_numbers, captions):
        if ('athway' or 'etwork') in caption:
            get_image(PMC, source, figure_number, id)
            pathway_found_counter+=1
    
    if pathway_found_counter == 0:
        no_pathway_papers.append(id)
    
    print('Paper id ' + str(id) + ' done')

def take_imgs_from_multiple_sites(ids):
    
    id_counter = 1
    for id in ids:
        
        if id.isnumeric():
            take_imgs_from_site(id)
        print(str(len(ids)-id_counter) + ' ids left')
        id_counter+=1
    
    create_no_pathway_file()
    create_not_found_file()
    print('All papers done')

# %%
df = pd.read_csv('Collected papers and classification proposal - Collected papers and classification proposal.csv')
ids = df['Pubmed ID'].tolist()

take_imgs_from_multiple_sites(ids)
# Out:
# Paper id 32145363 done
# 142 ids left
# Paper id 31226023 done
# 141 ids left
# Paper id 32330414 done
# 140 ids left
# Paper id 32511329 done
# 139 ids left
# Paper id 15194747 done
# 138 ids left
# Paper id 32132184 done
# 137 ids left
# Paper id 31034780 done
# 136 ids left
# Paper id 15331731 done
# 135 ids left
# Paper id 16877062 done
# 134 ids left
# Paper id 32225175 done
# 133 ids left
# Paper id 32227760 done
# 132 ids left
# 131 ids left
# Paper id 33899609 done
# 130 ids left
# Paper id 33482803 done
# 129 ids left
# Paper id 32265513 done
# 128 ids left
# Paper id 32219363 done
# 127 ids left
# Paper id 32976572 done
# 126 ids left
# Paper id 33436497 done
# 125 ids left
# Paper id 32353859 done
# 124 ids left
# Paper id 32358202 done
# 123 ids left
# Paper id 32346093 done
# 122 ids left
# Paper id 32835247 done
# 121 ids left
# Paper id 32227090 done
# 120 ids left
# Paper id 32398875 done
# 119 ids left
# output/32522207 exists
# Paper id 32522207 done
# 118 ids left
# Paper id 32835326 done
# 117 ids left
# Paper id 32546811 done
# 116 ids left
# output/28933406 exists
# output/28933406 exists
# Paper id 28933406 done
# 115 ids left
# Paper id 12441076 done
# 114 ids left
# Paper id 22013052 done
# 113 ids left
# Paper id 19109397 done
# 112 ids left
# Paper id 26203058 done
# 111 ids left
# Paper id 22553325 done
# 110 ids left
# 109 ids left
# Paper id 32587962 done
# 108 ids left
# Paper id 33206959 done
# 107 ids left
# Paper id 18753196 done
# 106 ids left
# Paper id 10799570 done
# 105 ids left
# Paper id 22751485 done
# 104 ids left
# Paper id 15527857 done
# 103 ids left
# Paper id 32048163 done
# 102 ids left
# Paper id 32591762 done
# 101 ids left
# Paper id 32663912 done
# 100 ids left
# Paper id 32732413 done
# 99 ids left
# Paper id 32778050 done
# 98 ids left
# Paper id 32807934 done
# 97 ids left
# Paper id 32946807 done
# 96 ids left
# Paper id 32714119 done
# 95 ids left
# Paper id 32511375 done
# 94 ids left
# Paper id 32270184 done
# 93 ids left
# Paper id 32386571 done
# 92 ids left
# Paper id 32763915 done
# 91 ids left
# 90 ids left
# 89 ids left
# output/32633718 exists
# Paper id 32633718 done
# 88 ids left
# Paper id 32968798 done
# 87 ids left
# 86 ids left
# 85 ids left
# 84 ids left
# Paper id 33046644 done
# 83 ids left
# Paper id 32877502 done
# 82 ids left
# Paper id 33082294 done
# 81 ids left
# Paper id 33082293 done
# 80 ids left
# Paper id 32528623 done
# 79 ids left
# Paper id 32869019 done
# 78 ids left
# output/33157038 exists
# Paper id 33157038 done
# 77 ids left
# Paper id 33116139 done
# 76 ids left
# Paper id 33147445 done
# 75 ids left
# Paper id 29642015 done
# 74 ids left
# Paper id 33125439 done
# 73 ids left
# Paper id 33116300 done
# 72 ids left
# Paper id 33147444 done
# 71 ids left
# Paper id 33184506 done
# 70 ids left
# 69 ids left
# Paper id 33278357 done
# 68 ids left
# Paper id 32142651 done
# 67 ids left
# Paper id 32944968 done
# 66 ids left
# Paper id 33244168 done
# 65 ids left
# Paper id 33270413 done
# 64 ids left
# Paper id 33060197 done
# 63 ids left
# Paper id 33277466 done
# 62 ids left
# output/33290397 exists
# Paper id 33290397 done
# 61 ids left
# Paper id 33139913 done
# 60 ids left
# Paper id 32972995 done
# 59 ids left
# Paper id 32972996 done
# 58 ids left
# Paper id 33307546 done
# 57 ids left
# Paper id 33188728 done
# 56 ids left
# Paper id 33296687 done
# 55 ids left
# Paper id 33159009 done
# 54 ids left
# Paper id 33324374 done
# 53 ids left
# 52 ids left
# Paper id 33402434 done
# 51 ids left
# Paper id 33422265 done
# 50 ids left
# Paper id 33231615 done
# 49 ids left
# output/33253796 exists
# output/33253796 exists
# output/33253796 exists
# Paper id 33253796 done
# 48 ids left
# Paper id 33451855 done
# 47 ids left
# Paper id 32191739 done
# 46 ids left
# Paper id 32416070 done
# 45 ids left
# Paper id 32645325 done
# 44 ids left
# Paper id 33547084 done
# 43 ids left
# Paper id 33576820 done
# 42 ids left
# Paper id 33576814 done
# 41 ids left
# Paper id 33495306 done
# 40 ids left
# Paper id 33536217 done
# 39 ids left
# Paper id 14607900 done
# 38 ids left
# output/33503446 exists
# Paper id 33503446 done
# 37 ids left
# Paper id 33590968 done
# 36 ids left
# Paper id 33361116 done
# 35 ids left
# Paper id 33732251 done
# 34 ids left
# Paper id 33655830 done
# 33 ids left
# Paper id 32967005 done
# 32 ids left
# Paper id 33686287 done
# 31 ids left
# Paper id 33524849 done
# 30 ids left
# Paper id 33492978 done
# 29 ids left
# Paper id 16125763 done
# 28 ids left
# Paper id 29245018 done
# 27 ids left
# Paper id 33713620 done
# 26 ids left
# Paper id 33727703 done
# 25 ids left
# Paper id 33723416 done
# 24 ids left
# Paper id 33328588 done
# 23 ids left
# 22 ids left
# Paper id 32205204 done
# 21 ids left
# Paper id 33348292 done
# 20 ids left
# Paper id 33211371 done
# 19 ids left
# Paper id 33811162 done
# 18 ids left
# Paper id 33784499 done
# 17 ids left
# Paper id 33984267 done
# 16 ids left
# Paper id 34029205 done
# 15 ids left
# Paper id 34010139 done
# 14 ids left
# Paper id 33845483 done
# 13 ids left
# Paper id 33879890 done
# 12 ids left
# Paper id 33880470 done
# 11 ids left
# Paper id 33915569 done
# 10 ids left
# Paper id 33976134 done
# 9 ids left
# Paper id 33915568 done
# 8 ids left
# Paper id 32733001 done
# 7 ids left
# Paper id 32979938 done
# 6 ids left
# output/32645325 exists
# Paper id 32645325 done
# 5 ids left
# Paper id 32529952 done
# 4 ids left
# Paper id 33451855 done
# 3 ids left
# Paper id 32589897 done
# 2 ids left
# Paper id 32555321 done
# 1 ids left
# 0 ids left
# All papers done

# %% [markdown]
# # Get figures from pmid that do not have PMCID

# %%
base_article_url = 'https://pubmed.ncbi.nlm.nih.gov/'
not_found_ids = []
no_pathway_papers = []

def create_no_pathway_file():

    with open('no_pathway_from_no_pmcids.txt', 'w') as f:
        for id in no_pathway_papers:
            f.write("%s\n" % id)

def get_page_soup(pmid):
    
    page = requests.get(base_article_url + str(pmid) + '/')
    soup = BeautifulSoup(page.content, 'html.parser')
    
    return soup

def get_fulltext_link(soup):
       
    full_text_links = soup.find_all(lambda tag: tag.name == 'a' and tag.get('class') == ['id-link'])
    links = [full_text_link['href'] for full_text_link in full_text_links]
    
    return links[0]

def get_full_text_soup(links):
    
    text_page = requests.get(links)
    text_soup = BeautifulSoup(text_page.content, 'html.parser')
    
    return text_soup

def get_fig_captions_pmid(text_soup):
    
    figcaption_codes = text_soup.find_all(lambda tag: tag.name == 'b' and tag.get('class') == ['c-article-section__figure-caption'])
    #captions = [caption_element.text for caption_element in fig]
    #figcaption_codes = soup.find_all('figcaption')
    
    return figcaption_codes
            
###############
def get_img_sources(soup):
       
    #img_containers = soup.find_all('a', class_ = 'ar-figure-viewer-modal figure scrollFig')
    #img_srcs = [img_container.findChild()['src'] for img_container in  img_containers]
      
    #img_containers = soup.find_all('a', class_ = 'highwire-figure-link highwire-figure-link-download')  
    #img_srcs = [img_container['href'] for img_container in img_containers]
    
    img_containers = soup.find_all('a', class_ = 'c-article-section__figure-link')
    img_srcs = [img_container['href'] for img_container in img_containers]
    return img_srcs

def get_image(source,fake_fig_num, id):
    
    response = requests.get('https://www.annualreviews.org/'+ source, stream=True)
    #response = requests.get(source)
    save_path = 'output_noPMCIDs/'+ str(id)
    try:
        os.makedirs(save_path)
    except:
        print(save_path + ' exists')
    
    #with open(save_path + '/' + caption + '.jpg', 'wb') as out_file:
       # shutil.copyfileobj(response.raw, out_file)         
    
  
    file = open(save_path + '/' + str(fake_fig_num) + source[-4:], "wb")
    file.write(response.content)
    file.close()
###############

def get_from_one_id(id):
    soup = get_page_soup(id)
    links = get_fulltext_link(soup)
    text_soup = get_full_text_soup(links)
    caption_codes = get_fig_captions_pmid(text_soup)
    img_sources = get_img_sources(text_soup)
    
    print(caption_codes)
    
    pathway_found_counter = 0
    for source, caption_code, fake_fig_num in zip(img_sources, caption_codes, range(1, len(img_sources) + 1)):
        if ('athway' or 'etwork') in caption_code:
            get_image(source, caption_code, fake_fig_num, id)
            pathway_found_counter += 1
     
    #for source, fake_fig_num in zip(img_sources, range(1, len(img_sources) + 1)):
        #get_image(source, fake_fig_num, id)
        #pathway_found_counter += 1
            
    if pathway_found_counter == 0:
        no_pathway_papers.append(id)
    
    print('Paper id ' + str(id) + ' done')    
    
def get_from_multi_ids(ids):
    id_counter = 1
    for id in ids:
        get_from_one_id(id)
        print(str(len(ids)-id_counter) + ' ids left')
        id_counter+=1
        
    create_no_pathway_file()

# %%
ids = open('not_found_ids.txt').read().splitlines()
get_from_multi_ids(ids)
# Out:
# []
# Paper id 31226023 done
# 24 ids left
# []
# Paper id 32219363 done
# 23 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Dysregulated bronchoalveolar immune landscapes in patients with severe COVID-19 infection.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: T cell clonal expansion in BALF from patients with COVID-19.</b>]
# Paper id 32398875 done
# 22 ids left
# []
# Paper id 32546811 done
# 21 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Illustration of the experimental setup and the patient cohort used in this study.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Identification, distribution and classification of cells from the upper respiratory tract.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: Inferred differentiation pathways for epithelial cells from the upper respiratory tract.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: Immune–epithelial cell interaction in COVID-19.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig5">Fig. 5: Differences between moderate and critical COVID-19 severity are attributed to non-resident macrophage over-expression of cytokines/chemokines and extravasation.</b>]
# Paper id 32591762 done
# 20 ids left
# []
# Paper id 32732413 done
# 19 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Immunophenotyping reveals distinct features of the immune system in patients with COVID-19.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Coexistent anti-SARS-CoV-2 antibody responses and disruption to the B cell compartment in patients with COVID-19.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: Patients with COVID-19 display dysregulated cytokine responses.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: Patients with COVID-19 display a disrupted monocyte and dendritic cell phenotype.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig5">Fig. 5: Patients with COVID-19 display selective cytopenia in particular T cell subsets and coexistent active cycling and exhausted phenotype of residual T cells.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig6">Fig. 6: COVID-IP parameters associated with patient prognosis.</b>]
# Paper id 32807934 done
# 18 ids left
# []
# Paper id 33082294 done
# 17 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: The S protein of SARS-CoV-2 binds to cholesterol.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: HDL enhances the entry of SARS-CoV-2 through SARS-2-S1 protein.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: SR-B1 expression confers susceptibility to SARS-CoV-2 infection.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: SR-B1 mediates SARS-CoV-2 attachment and entry.</b>]
# Paper id 33244168 done
# 16 ids left
# []
# Paper id 33270413 done
# 15 ids left
# []
# Paper id 33139913 done
# 14 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Discovery GWAS and meta-analysis results.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Summary of TWAS results.</b>]
# Paper id 33307546 done
# 13 ids left
# []
# Paper id 33576814 done
# 12 ids left
# []
# Paper id 33536217 done
# 11 ids left
# []
# Paper id 14607900 done
# 10 ids left
# []
# Paper id 33655830 done
# 9 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Genome-wide knockout screens in human cells identify host factors for SARS-CoV-2 and HCoV-229E infection.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Validation of genetic screens.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: PI3K type 3 is a druggable target against SARS-CoV-2 and other coronaviruses.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: TMEM41B is a host factor for HCoV-229E.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig5">Fig. 5: <i>TMEM106B</i> is a bona fide proviral host factor for SARS-CoV-2 replication.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig6">Fig. 6: <i>TMEM106B</i> expression in epithelial cells from human airways correlates with SARS-CoV-2 infection.</b>]
# Paper id 33686287 done
# 8 ids left
# []
# Paper id 33492978 done
# 7 ids left
# []
# Paper id 16125763 done
# 6 ids left
# []
# Paper id 29245018 done
# 5 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Clofazimine inhibits the replication of a broad spectrum of human-pathogenic coronaviruses in human cellular models.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Clofazimine interferes with several steps of the virus life cycle.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: Prophylactic and therapeutic treatment with clofazimine reduces disease in a hamster model of SARS-CoV-2 infection.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: Clofazimine exhibits antiviral synergy with remdesivir in hamsters.</b>]
# Paper id 33727703 done
# 4 ids left
# []
# Paper id 33811162 done
# 3 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Joint analysis of SARS-CoV-2 and SARS-CoV virus–host protein–protein interactomes.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Multi-level profiling of SARS-CoV-2 and SARS-CoV infection.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: Phosphorylation and ubiquitination of SARS-CoV-2 and SARS-CoV viral proteins.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: A network diffusion approach enables identification of molecular pathways linking protein–protein interactions with downstream changes in the host proteome.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig5">Fig. 5: Identification of pathways targeted by SARS-CoV-2 using a multi-omics profiling approach enables systematic testing of candidate antiviral therapies.</b>]
# Paper id 33845483 done
# 2 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Experimental and computational pipeline for a COVID-19 autopsy atlas.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: A single-cell and single-nucleus atlas of COVID-19 lung.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: SARS-CoV-2 RNA<sup>+</sup> single cells are enriched for phagocytic and endothelial cells.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: Composition and expression differences between COVID-19 and healthy lungs and between infected and uninfected regions within COVID-19 lungs.</b>]
# Paper id 33915569 done
# 1 ids left
# [<b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig1">Fig. 1: Study design and cellular landscape.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig2">Fig. 2: Immune responses in COVID-19.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig3">Fig. 3: Impaired lung regeneration and sources of inflammation.</b>, <b class="c-article-section__figure-caption" data-test="figure-caption-text" id="Fig4">Fig. 4: Pathological fibroblasts and ensuing fibrosis in COVID-19.</b>]
# Paper id 33915568 done
# 0 ids left
